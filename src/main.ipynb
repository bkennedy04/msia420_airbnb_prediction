# %% [markdown]
# # WSDM - KKBox's Churn Prediction Challenge
# *Can you predict when subscribers will churn?*

# %% [markdown]
# **Outline**
#
# * [Read Data](#read)
# * [Exploratory Data Analysis](#eda)
# * [Feature Creation and Preprocessing](#preprocess)
# * [Model and Score](#model)
# * [Predicition](#predict)
# * [Reference](#reference)

# %% [markdown]
# ---

# %%
# %load_ext watermark

# %%
import os
import pandas as pd
import numpy as np

# %%
# %watermark -a 'PredictiveII' -d -t -v -p pandas,numpy,sklearn,watermark
# Out:
# PredictiveII 2018-01-29 22:58:13
#
# CPython 3.6.3
# IPython 6.1.0
#
# pandas 0.20.3
# numpy 1.13.3
# sklearn 0.19.1
# watermark 1.6.0

# %% [markdown]
# ## <a id="read">Read Data</a>

# %% [markdown]
# ### **Train**:
# The train data consists of users whose subscription expires within the month of February 2017
# In other words, these are the user ids whose subscription expires in February 2017. When we merge them with their transaction records, their lastest expire date should be the month of February 2017. We should have some more data related to their previous behavior after merging with transaction datatset.

# %%
# read data
data_dir = os.path.join('..', 'data')

train_path = os.path.join(data_dir, 'train_v2.csv')
transactions_path = os.path.join(data_dir, 'transactions_v2.csv') 
user_logs_path = os.path.join(data_dir, 'user_logs_v2.csv') 
members_path = os.path.join(data_dir, 'members_v3.csv') 
sample_submission_path = os.path.join(data_dir, 'sample_submission_v2.csv')

train = pd.read_csv(train_path)
transaction = pd.read_csv(transactions_path)
user_log = pd.read_csv(user_logs_path)
member = pd.read_csv(members_path)
sample_submission = pd.read_csv(sample_submission_path)

# %%
train.head()
# Out:
#                                            msno  is_churn
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1

# %%
train.shape
# Out:
# (970960, 2)

# %% [markdown]
# ### Transaction

# %% [markdown]
# * **transaction_date**: should be the date this user make a payment
# * **membership_expire_date**: the date that the membership expires before the payment?

# %%
transaction['membership_expire_date'] = pd.to_datetime(transaction['membership_expire_date'], format='%Y%m%d', errors='ignore')
#transaction['membership_expire_year'] = transaction['membership_expire_date'].apply(lambda x: x.year)
#transaction['membership_expire_month'] = transaction['membership_expire_date'].apply(lambda x: x.month)
#transaction['membership_expire_day'] = transaction['membership_expire_date'].apply(lambda x: x.day)

# %%
transaction['transaction_date'] = pd.to_datetime(transaction['transaction_date'], format='%Y%m%d', errors='ignore')
#transaction['transaction_year'] = transaction['transaction_date'].apply(lambda x: x.year)
#transaction['transaction_month'] = transaction['transaction_date'].apply(lambda x: x.month)
#transaction['transaction_day'] = transaction['transaction_date'].apply(lambda x: x.day)

# %%
transaction.head()
# Out:
#                                            msno  payment_method_id  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#   transaction_date membership_expire_date  is_cancel
# 0       2017-01-31             2017-05-04          0
# 1       2015-08-09             2019-04-12          0
# 2       2017-03-03             2017-04-22          0
# 3       2017-03-29             2017-03-31          1
# 4       2017-03-23             2017-04-23          0

# %%
transaction.shape
# Out:
# (1431009, 9)

# %% [markdown]
# **Questions**
#
# * How to generate the submission? Where do those 907471 msno's coming from?
# * The train data consists of users whose subscription expires within the month of February 2017. When I merge with transaction data, the menbership expire date for those ids have a lot of different membership_expire_date. What does that mean? Shouldn't all these id in the train data with the membership_expire_date in 2017 Feb?
# * Don't understand what they are discuess [here](https://www.kaggle.com/c/kkbox-churn-prediction-challenge/discussion/39756)
# * Should spend more time on reading the [Should I stay or should I go? - KKBox EDA
# ](https://www.kaggle.com/headsortails/should-i-stay-or-should-i-go-kkbox-eda), [Churn or No Churn - Exploration Data Analysis
# ](https://www.kaggle.com/rastaman/churn-or-no-churn-exploration-data-analysis)
# * For some records in transaciton, the membership_expire_date is far from today, such as in the year of 2020, but they are labeled as churn. What does that mean? Remind that the criteria of "churn" is **no new valid service subscription within 30 days after the current membership expires.**

# %%
transaction[(transaction['membership_expire_year']==2017) & (transaction['membership_expire_month']==2)].shape
# Out:
# (350, 15)

# %%
temp = pd.merge(train, transaction, on='msno', how='left')

# %%
temp.shape
# Out:
# (1169418, 16)

# %%
temp2 = temp[temp['payment_method_id'].notnull()]

# %%
temp2.shape
# Out:
# (1132036, 16)

# %%
len(train.msno.unique())
# Out:
# 970960

# %%
len(temp2.msno.unique())
# Out:
# 933578

# %%
temp2.head()
# Out:
#                                            msno  is_churn  payment_method_id  \
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1               36.0
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1               17.0
# 3  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1               15.0
# 4  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 5  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 1               30.0            180.0               180.0            0.0
# 2               60.0              0.0                 0.0            0.0
# 3               90.0            300.0               300.0            0.0
# 4               30.0            149.0               149.0            1.0
# 5               30.0            149.0               149.0            1.0
#
#   transaction_date membership_expire_date  is_cancel  membership_expire_year  \
# 1       2017-03-11             2017-04-11        0.0                  2017.0
# 2       2017-03-11             2017-03-14        0.0                  2017.0
# 3       2017-03-14             2017-06-15        0.0                  2017.0
# 4       2015-09-08             2017-06-08        0.0                  2017.0
# 5       2015-09-08             2017-07-08        0.0                  2017.0
#
#    membership_expire_month  membership_expire_day  transaction_year  \
# 1                      4.0                   11.0            2017.0
# 2                      3.0                   14.0            2017.0
# 3                      6.0                   15.0            2017.0
# 4                      6.0                    8.0            2015.0
# 5                      7.0                    8.0            2015.0
#
#    transaction_month  transaction_day
# 1                3.0             11.0
# 2                3.0             11.0
# 3                3.0             14.0
# 4                9.0              8.0
# 5                9.0              8.0

# %%
temp2.query('msno=="8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ="').sort_values(by='transaction_date',ascending=True)
# Out:
#                                             msno  is_churn  payment_method_id  \
# 11  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 13  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 4   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 5   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 8   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 9   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 7   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 10  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 6   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 12  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
#
#     payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 11               30.0            149.0               149.0            1.0
# 13               30.0            149.0               149.0            1.0
# 4                30.0            149.0               149.0            1.0
# 5                30.0            149.0               149.0            1.0
# 8                30.0            149.0               149.0            1.0
# 9                30.0            149.0               149.0            1.0
# 7                30.0            149.0               149.0            1.0
# 10               30.0            149.0               149.0            1.0
# 6                30.0            149.0               149.0            1.0
# 12               30.0            149.0               149.0            1.0
#
#    transaction_date membership_expire_date  is_cancel  membership_expire_year  \
# 11       2015-08-08             2017-05-09        0.0                  2017.0
# 13       2015-08-08             2017-04-08        0.0                  2017.0
# 4        2015-09-08             2017-06-08        0.0                  2017.0
# 5        2015-09-08             2017-07-08        0.0                  2017.0
# 8        2015-10-08             2017-09-08        0.0                  2017.0
# 9        2015-10-08             2017-08-08        0.0                  2017.0
# 7        2015-11-08             2017-10-08        0.0                  2017.0
# 10       2015-11-08             2017-11-07        0.0                  2017.0
# 6        2015-12-08             2017-12-08        0.0                  2017.0
# 12       2015-12-08             2018-01-08        0.0                  2018.0
#
#     membership_expire_month  membership_expire_day  transaction_year  \
# 11                      5.0                    9.0            2015.0
# 13                      4.0                    8.0            2015.0
# 4                       6.0                    8.0            2015.0
# 5                       7.0                    8.0            2015.0
# 8                       9.0                    8.0            2015.0
# 9                       8.0                    8.0            2015.0
# 7                      10.0                    8.0            2015.0
# 10                     11.0                    7.0            2015.0
# 6                      12.0                    8.0            2015.0
# 12                      1.0                    8.0            2015.0
#
#     transaction_month  transaction_day
# 11                8.0              8.0
# 13                8.0              8.0
# 4                 9.0              8.0
# 5                 9.0              8.0
# 8                10.0              8.0
# 9                10.0              8.0
# 7                11.0              8.0
# 10               11.0              8.0
# 6                12.0              8.0
# 12               12.0              8.0

# %%
temp2.head(30)
# Out:
#                                             msno  is_churn  payment_method_id  \
# 1   f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1               36.0
# 2   zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1               17.0
# 3   zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1               15.0
# 4   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 5   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 6   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 7   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 8   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 9   8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 10  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 11  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 12  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 13  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1               41.0
# 14  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 15  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 16  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 17  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 18  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 19  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 20  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 21  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1               41.0
# 22  ibIHVYBqxGwrSExE63/omeDD99M5vYB3CN2HzkEY+eM=         1               40.0
# 23  kVmM8X4iBPCOfK/m1l3KR7LjFoxD1EcKYCc76F5IAWw=         1               41.0
# 24  moRTKhKIDvb+C8ZHOgmaF4dXMLk0jOn65d7a8tQ2Eds=         1               38.0
# 25  dW/tPZMDh2Oz/ksduEctJbsz0MXw3kay/1AlZCq3EbI=         1               38.0
# 26  dW/tPZMDh2Oz/ksduEctJbsz0MXw3kay/1AlZCq3EbI=         1               38.0
# 27  otEcMhAX3mU4gumUSogqgteN3oaNmhdmTkoof2iRYEE=         1               40.0
# 28  otEcMhAX3mU4gumUSogqgteN3oaNmhdmTkoof2iRYEE=         1               40.0
# 29  t5rqTxCnG7s5VBgEfdkQCezv5KBK7+DMujNibYgylrs=         1               38.0
# 30  dfLS2/Pom6O3iUpo+mf/K1Bc6g+7LFKzoNf+zlJtDoQ=         1               41.0
#
#     payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 1                30.0            180.0               180.0            0.0
# 2                60.0              0.0                 0.0            0.0
# 3                90.0            300.0               300.0            0.0
# 4                30.0            149.0               149.0            1.0
# 5                30.0            149.0               149.0            1.0
# 6                30.0            149.0               149.0            1.0
# 7                30.0            149.0               149.0            1.0
# 8                30.0            149.0               149.0            1.0
# 9                30.0            149.0               149.0            1.0
# 10               30.0            149.0               149.0            1.0
# 11               30.0            149.0               149.0            1.0
# 12               30.0            149.0               149.0            1.0
# 13               30.0            149.0               149.0            1.0
# 14               30.0             99.0                99.0            1.0
# 15               30.0             99.0                99.0            1.0
# 16               30.0             99.0                99.0            1.0
# 17               30.0             99.0                99.0            1.0
# 18               30.0             99.0                99.0            1.0
# 19               30.0             99.0                99.0            1.0
# 20               30.0             99.0                99.0            1.0
# 21               30.0             99.0                99.0            1.0
# 22               30.0            149.0               149.0            1.0
# 23               30.0             99.0                99.0            1.0
# 24              410.0           1788.0              1788.0            0.0
# 25               90.0            477.0               477.0            0.0
# 26               30.0            149.0               149.0            0.0
# 27               30.0            149.0               149.0            1.0
# 28               30.0            149.0               149.0            1.0
# 29               30.0            149.0               149.0            0.0
# 30               30.0             99.0                99.0            1.0
#
#    transaction_date membership_expire_date  is_cancel  membership_expire_year  \
# 1        2017-03-11             2017-04-11        0.0                  2017.0
# 2        2017-03-11             2017-03-14        0.0                  2017.0
# 3        2017-03-14             2017-06-15        0.0                  2017.0
# 4        2015-09-08             2017-06-08        0.0                  2017.0
# 5        2015-09-08             2017-07-08        0.0                  2017.0
# 6        2015-12-08             2017-12-08        0.0                  2017.0
# 7        2015-11-08             2017-10-08        0.0                  2017.0
# 8        2015-10-08             2017-09-08        0.0                  2017.0
# 9        2015-10-08             2017-08-08        0.0                  2017.0
# 10       2015-11-08             2017-11-07        0.0                  2017.0
# 11       2015-08-08             2017-05-09        0.0                  2017.0
# 12       2015-12-08             2018-01-08        0.0                  2018.0
# 13       2015-08-08             2017-04-08        0.0                  2017.0
# 14       2017-01-17             2017-07-21        0.0                  2017.0
# 15       2016-12-01             2017-06-05        0.0                  2017.0
# 16       2016-10-01             2017-04-05        0.0                  2017.0
# 17       2016-11-01             2017-05-05        0.0                  2017.0
# 18       2017-01-17             2017-06-20        1.0                  2017.0
# 19       2017-02-16             2017-08-18        0.0                  2017.0
# 20       2017-01-01             2017-07-06        0.0                  2017.0
# 21       2017-03-16             2017-09-18        0.0                  2017.0
# 22       2017-03-16             2017-03-14        1.0                  2017.0
# 23       2017-03-07             2017-03-07        1.0                  2017.0
# 24       2017-03-24             2018-05-13        0.0                  2018.0
# 25       2017-03-28             2017-07-07        0.0                  2017.0
# 26       2017-03-07             2017-04-08        0.0                  2017.0
# 27       2017-03-26             2017-05-25        0.0                  2017.0
# 28       2017-02-26             2017-04-24        0.0                  2017.0
# 29       2017-02-16             2017-04-17        0.0                  2017.0
# 30       2017-03-04             2017-05-05        0.0                  2017.0
#
#     membership_expire_month  membership_expire_day  transaction_year  \
# 1                       4.0                   11.0            2017.0
# 2                       3.0                   14.0            2017.0
# 3                       6.0                   15.0            2017.0
# 4                       6.0                    8.0            2015.0
# 5                       7.0                    8.0            2015.0
# 6                      12.0                    8.0            2015.0
# 7                      10.0                    8.0            2015.0
# 8                       9.0                    8.0            2015.0
# 9                       8.0                    8.0            2015.0
# 10                     11.0                    7.0            2015.0
# 11                      5.0                    9.0            2015.0
# 12                      1.0                    8.0            2015.0
# 13                      4.0                    8.0            2015.0
# 14                      7.0                   21.0            2017.0
# 15                      6.0                    5.0            2016.0
# 16                      4.0                    5.0            2016.0
# 17                      5.0                    5.0            2016.0
# 18                      6.0                   20.0            2017.0
# 19                      8.0                   18.0            2017.0
# 20                      7.0                    6.0            2017.0
# 21                      9.0                   18.0            2017.0
# 22                      3.0                   14.0            2017.0
# 23                      3.0                    7.0            2017.0
# 24                      5.0                   13.0            2017.0
# 25                      7.0                    7.0            2017.0
# 26                      4.0                    8.0            2017.0
# 27                      5.0                   25.0            2017.0
# 28                      4.0                   24.0            2017.0
# 29                      4.0                   17.0            2017.0
# 30                      5.0                    5.0            2017.0
#
#     transaction_month  transaction_day
# 1                 3.0             11.0
# 2                 3.0             11.0
# 3                 3.0             14.0
# 4                 9.0              8.0
# 5                 9.0              8.0
# 6                12.0              8.0
# 7                11.0              8.0
# 8                10.0              8.0
# 9                10.0              8.0
# 10               11.0              8.0
# 11                8.0              8.0
# 12               12.0              8.0
# 13                8.0              8.0
# 14                1.0             17.0
# 15               12.0              1.0
# 16               10.0              1.0
# 17               11.0              1.0
# 18                1.0             17.0
# 19                2.0             16.0
# 20                1.0              1.0
# 21                3.0             16.0
# 22                3.0             16.0
# 23                3.0              7.0
# 24                3.0             24.0
# 25                3.0             28.0
# 26                3.0              7.0
# 27                3.0             26.0
# 28                2.0             26.0
# 29                2.0             16.0
# 30                3.0              4.0

# %%
temp2 = temp.groupby(['msno']).agg({'payment_method_id': 'count'}).reset_index()

# %%
temp2[temp2.payment_method_id>1].sort_values(by='payment_method_id', ascending=False).head()
# Out:
#                                                 msno  payment_method_id
# 137444  72gJqt1O31E/WoxAEYFn9LHNI6mAZFGera5Q6gvsFkA=                208
# 119705  5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=                172
# 398175  OGKDrZQDB3yewZhoSd5qqvmG5A1GcNTYMexO95NlH+g=                148
# 520336  WHsCtkOVsauvqBL0ULuG38887y7aU8GXdCmJMjw6hjQ=                145
# 461063  SNlFRAsmUqnXKPofSXA8WYUc5DtmLcUMy4pXSJ3Ohz0=                131

# %%
sample_merge = pd.merge(sample_submission,transaction, on='msno',how='left')

# %%
sample_submission.shape
# Out:
# (907471, 2)

# %%
sample_merge.head()
# Out:
#                                            msno  is_churn  payment_method_id  \
# 0  4n+fXlyJvfQnTeKXTWT507Ll4JVYGrOC8LHCfwBmPE4=         0               41.0
# 1  aNmbC1GvFUxQyQUidCVmfbQ0YeCuwkPzEdQ0RwWyeZM=         0               34.0
# 2  rFC9eSG/tMuzpre6cwcMLZHEYM89xY02qcz7HL4//jc=         0               41.0
# 3  WZ59dLyrQcE7ft06MZ5dj40BnlYQY7PHgg/54+HaCSE=         0               41.0
# 4  aky/Iv8hMp1/V/yQHLtaVuEmmAxkB5GuasQZePJ7NU4=         0               30.0
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0               30.0             99.0                99.0            1.0
# 1               30.0            149.0               149.0            1.0
# 2               30.0             99.0                99.0            1.0
# 3               30.0             99.0                99.0            1.0
# 4               30.0            129.0               129.0            1.0
#
#   transaction_date membership_expire_date  is_cancel  membership_expire_year  \
# 0       2017-03-18             2017-04-18        0.0                  2017.0
# 1       2017-03-31             2017-04-30        0.0                  2017.0
# 2       2017-03-15             2017-04-15        0.0                  2017.0
# 3       2017-03-27             2017-04-27        0.0                  2017.0
# 4       2017-03-22             2017-04-21        0.0                  2017.0
#
#    membership_expire_month  membership_expire_day  transaction_year  \
# 0                      4.0                   18.0            2017.0
# 1                      4.0                   30.0            2017.0
# 2                      4.0                   15.0            2017.0
# 3                      4.0                   27.0            2017.0
# 4                      4.0                   21.0            2017.0
#
#    transaction_month  transaction_day
# 0                3.0             18.0
# 1                3.0             31.0
# 2                3.0             15.0
# 3                3.0             27.0
# 4                3.0             22.0

# %%
sample_merge.shape
# Out:
# (973285, 16)

# %%
len(sample_merge[sample_merge['payment_method_id'].notnull()]['msno'].unique())
# Out:
# 907470

# %% [markdown]
# ## <a id="eda">Exploratory Data Analysis</a>
